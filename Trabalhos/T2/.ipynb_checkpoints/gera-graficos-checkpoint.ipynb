# %%
import os
import matplotlib.pyplot as plt

# %%
diretorio = os.getcwd()
print("O diretório atual é:", diretorio)
# novo_diretorio = './v1'
# os.chdir(novo_diretorio)
# diretorio_atual = os.getcwd()
# print("O diretório atual é:", diretorio_atual)
# Out:
# O diretório atual é: /home/eduardo/Área de Trabalho/T1/Icc-/Trabalhos/T2

# %%
x = [64,128,200,256,512,600,800,1024,2000,3000,4096,6000,7000,10000,50000,100000,1000000,10000000,100000000]

# %% [markdown]
# ## TEMPO DE EXECUÇÃO

# %%
tempo_ajustePol_geraSL = []
tempo_ajustePol_otimizado_geraSL = []
tempo_ajustePol_solSL = []
tempo_ajustePol_otimizado_solSL = []
tempo_ajustePol_calcRes = []
tempo_ajustePol_otimizado_calcRes = []

diretorio = './v1'
os.chdir(diretorio)
for n in x:
    arquivo = 'L3_'+ str(n) + '.txt'
    with open("resultados/"+arquivo, 'r') as arquivo:
        linhas = arquivo.readlines()
        
    for n_linha, linha in enumerate(linhas):
            if n_linha == 5: #GERA SL
                partes = linha.split("\n")
#                 print(partes)
                valor = float(partes[0].replace(" ", ""))
                tempo_ajustePol_geraSL.append(valor)

            if n_linha == 6:#SOL SL
                partes = linha.split("\n")
#                 print(partes)
                valor = float(partes[0].replace(" ", ""))
                tempo_ajustePol_solSL.append(valor)
                
            if n_linha == 7:#CALCULA RESIDUO SL
                partes = linha.split("\n")
#                 print(partes)
                valor = float(partes[0].replace(" ", ""))
                tempo_ajustePol_calcRes.append(valor)
        
        
os.chdir('..')
diretorio = './v2'
os.chdir(diretorio)
for n in x:
    arquivo = 'L3_' + str(n) + '.txt'
        
    with open("resultados/" + arquivo, 'r') as arquivo:
        linhas = arquivo.readlines()
        
        for n_linha, linha in enumerate(linhas):
            if n_linha == 5: #GERA SL
                partes = linha.split("\n")
#                 print(partes)
                valor = float(partes[0].replace(" ", ""))
                tempo_ajustePol_otimizado_geraSL.append(valor)

            if n_linha == 6:#SOL SL
                partes = linha.split("\n")
#                 print(partes)
                valor = float(partes[0].replace(" ", ""))
                tempo_ajustePol_otimizado_solSL.append(valor)
                
            if n_linha == 7:#CALCULA RESIDUO SL
                partes = linha.split("\n")
#                 print(partes)
                valor = float(partes[0].replace(" ", ""))
                tempo_ajustePol_otimizado_calcRes.append(valor)
        
#         for linha in linhas:
#             if "multmatvet:" in linha:
#                 partes = linha.split(":")
#                 valor = float(partes[1].strip())
#                 tempo_multmatvet.append(valor)
#             if "multmatvet_otimizado:" in linha:
#                 partes = linha.split(":")
#                 valor = float(partes[1].strip())
#                 tempo_multmatvet_otimizado.append(valor)
#             if "multmatmat:" in linha:
#                 partes = linha.split(":")
#                 valor = float(partes[1].strip())
#                 tempo_multmatmat.append(valor)
#             if "multmatmat_otimizado:" in linha:
#                 partes = linha.split(":")
#                 valor = float(partes[1].strip())
#                 tempo_multmatmat_otimizado.append(valor)
os.chdir('..')

# %% [markdown]
# ### Gráfico

# %%
fig, axs = plt.subplots(1, 3, figsize=(18, 6))

# Gráfico 1 - GERA SL
axs[0].plot(x, tempo_ajustePol_geraSL, label='Não otimizado', linestyle='-', marker='o', color='b')
axs[0].plot(x, tempo_ajustePol_otimizado_geraSL, label='Otimizado', linestyle='-', marker='o', color='r')
axs[0].legend()

axs[0].set_xscale('log')  # Configuração do eixo x em escala logarítmica
axs[0].set_xlabel('Tamanho (K)')
axs[0].set_ylabel('Tempo (ms)')
axs[0].set_title('GERA SL', fontsize=16)

# Gráfico 2 - SOLUCIONA SL
axs[1].plot(x, tempo_ajustePol_solSL, label='Não otimizado', linestyle='-', marker='o', color='b')
axs[1].plot(x, tempo_ajustePol_otimizado_solSL, label='Otimizado', linestyle='-', marker='o', color='r')
axs[1].legend()

axs[1].set_xscale('log')  # Configuração do eixo x em escala logarítmica
axs[1].set_xlabel('Tamanho (K)')
axs[1].set_ylabel('Tempo (ms)')
axs[1].set_title('SOLUCIONA SL', fontsize=16)

# Gráfico 3 - CALCULA RESIDUO SL
axs[2].plot(x, tempo_ajustePol_calcRes, label='Não otimizado', linestyle='-', marker='o', color='b')
axs[2].plot(x, tempo_ajustePol_otimizado_calcRes, label='Otimizado', linestyle='-', marker='o', color='r')
axs[2].legend()

axs[2].set_xscale('log')  # Configuração do eixo x em escala logarítmica
axs[2].set_xlabel('Tamanho (K)')
axs[2].set_ylabel('Tempo (ms)')
axs[2].set_title('CALCULA RESIDUO SL', fontsize=16)

fig.suptitle('Tempo (ms)', fontsize=20)

plt.savefig("tempo.png")

plt.show()

# %% [markdown]
# ## BANDA DE MEMÓRIA (L3)

# %%
l3_ajustePol_geraSL = []
l3_ajustePol_otimizado_geraSL = []
l3_ajustePol_calcRes = []
l3_ajustePol_otimizado_calcRes = []
# print("O diretório atual é:", diretorio)
diretorio = './v1'
os.chdir(diretorio)
# print("O diretório atual é:", diretorio)
for n in x: #Para a versão 1 do código
    arquivo = 'L3_' + str(n) + '.txt'
        
    with open("resultados/" + arquivo, 'r') as arquivo:
        linhas = arquivo.readlines()

        for n_linha, linha in enumerate(linhas):
            if n_linha == 36: #GERA SL
                partes = linha.split("|")
                valor = float(partes[2].replace(" ", ""))
                l3_ajustePol_geraSL.append(valor)

            if n_linha == 102:#CALCULA RESIDUO SL
                partes = linha.split("|")
                valor = float(partes[2].replace(" ", ""))
                l3_ajustePol_calcRes.append(valor)

                
# Retorna ao diretório pai antes de iniciar o próximo laço
os.chdir('..')
diretorio = './v2'
os.chdir(diretorio)
for n in x:
    arquivo = 'L3_' + str(n) + '.txt'
        
    with open("resultados/" + arquivo, 'r') as arquivo:
        linhas = arquivo.readlines()

        for n_linha, linha in enumerate(linhas):
            if n_linha == 36: #GERA SL
                partes = linha.split("|")
                valor = float(partes[2].replace(" ", ""))
                l3_ajustePol_otimizado_geraSL.append(valor)

            if n_linha == 102:#CALCULA RESIDUO SL
                partes = linha.split("|")
                valor = float(partes[2].replace(" ", ""))
                l3_ajustePol_otimizado_calcRes.append(valor)
os.chdir('..')

# %% [markdown]
# ### Gráfico

# %%
fig, axs = plt.subplots(1, 2, figsize=(16, 8))

# Gráfico 1 - GERA SL
axs[0].plot(x, l3_ajustePol_geraSL, label='Não otimizado', linestyle='-', marker='o', color='b')
axs[0].plot(x, l3_ajustePol_otimizado_geraSL, label='Otimizado', linestyle='-', marker='o', color='r')
axs[0].legend()

axs[0].set_xscale('log')
axs[0].set_xlabel('Tamanho (K)')
axs[0].set_ylabel('Banda de Memória (L3)')
axs[0].set_title('GERA SL', fontsize=16)

# Gráfico 2 - CALCULA RESIDUO SL
axs[1].plot(x, l3_ajustePol_calcRes, label='Não otimizado', linestyle='-', marker='o', color='b')
axs[1].plot(x, l3_ajustePol_otimizado_calcRes, label='Otimizado', linestyle='-', marker='o', color='r')
axs[1].legend()

axs[1].set_xscale('log')
axs[1].set_xlabel('Tamanho (K)')
axs[1].set_ylabel('Banda de Memória (L3)')
axs[1].set_title('CALCULA RESIDUO SL', fontsize=16)

fig.suptitle('Banda de Memória (L3)', fontsize=20)

plt.savefig("l3_operacoes.png")

plt.show()

# %% [markdown]
# ## L2CACHE miss

# %%
l2_ajustePol_geraSL = []
l2_ajustePol_otimizado_geraSL = []
l2_ajustePol_calcRes = []
l2_ajustePol_otimizado_calcRes = []
diretorio = './v1'
os.chdir(diretorio)
# print("O diretório atual é:", diretorio)
for n in x: #Para a versão 1 do código
    arquivo = 'L2CACHE_' + str(n) + '.txt'
        
    with open("resultados/" + arquivo, 'r') as arquivo:
        linhas = arquivo.readlines()

        for n_linha, linha in enumerate(linhas):
            if n_linha == 39: #GERA SL
                partes = linha.split("|")
                valor = float(partes[2].replace(" ", ""))
                l2_ajustePol_geraSL.append(valor)

            if n_linha == 105:#CALCULA RESIDUO SL
                partes = linha.split("|")
                valor = float(partes[2].replace(" ", ""))
                l2_ajustePol_calcRes.append(valor)

                
# Retorna ao diretório pai antes de iniciar o próximo laço
os.chdir('..')
diretorio = './v2'
os.chdir(diretorio)
for n in x:
    arquivo = 'L2CACHE_' + str(n) + '.txt'
        
    with open("resultados/" + arquivo, 'r') as arquivo:
        linhas = arquivo.readlines()

        for n_linha, linha in enumerate(linhas):
            if n_linha == 39: #GERA SL
                partes = linha.split("|")
                valor = float(partes[2].replace(" ", ""))
                l2_ajustePol_otimizado_geraSL.append(valor)

            if n_linha == 105:#CALCULA RESIDUO SL
                partes = linha.split("|")
                valor = float(partes[2].replace(" ", ""))
                l2_ajustePol_otimizado_calcRes.append(valor)
os.chdir('..')

# %% [markdown]
# ### Gráficos

# %%
fig, axs = plt.subplots(1, 2, figsize=(16, 8))

# Gráfico 1 - GERA SL
axs[0].plot(x, l2_ajustePol_geraSL, label='Não otimizado', linestyle='-', marker='o', color='b')
axs[0].plot(x, l2_ajustePol_otimizado_geraSL, label='Otimizado', linestyle='-', marker='o', color='r')
axs[0].legend()

axs[0].set_xscale('log')
axs[0].set_xlabel('Tamanho (K)')
axs[0].set_ylabel('CACHE MISS RATIO')
axs[0].set_title('GERA SL', fontsize=16)

# Gráfico 2 - CALCULA RESIDUO SL
axs[1].plot(x, l2_ajustePol_calcRes, label='Não otimizado', linestyle='-', marker='o', color='b')
axs[1].plot(x, l2_ajustePol_otimizado_calcRes, label='Otimizado', linestyle='-', marker='o', color='r')
axs[1].legend()

axs[1].set_xscale('log')
axs[1].set_xlabel('Tamanho (K)')
axs[1].set_ylabel('CACHE MISS RATIO')
axs[1].set_title('CALCULA RESIDUO SL', fontsize=16)

fig.suptitle('CACHE MISS RATIO', fontsize=20)

plt.savefig("l2_CACHEmiss.png")

plt.show()

# %% [markdown]
# ## ENERGY

# %%
energy_multmatvet = []
energy_multmatvet_otimizado = []
energy_multmatmat = []
energy_multmatmat_otimizado = []

for n in x:
    arquivo = 'ENERGY_' + str(n) + '.txt'
        
    with open("resultados/" + arquivo, 'r') as arquivo:
        linhas = arquivo.readlines()

        for n_linha, linha in enumerate(linhas):
            if n_linha == 43:
                partes = linha.split("|")
                valor = float(partes[2].replace(" ", ""))
                energy_multmatvet.append(valor)
            
            if n_linha == 82:
                partes = linha.split("|")
                valor = float(partes[2].replace(" ", ""))
                energy_multmatvet_otimizado.append(valor)

            if n_linha == 121:
                partes = linha.split("|")
                valor = float(partes[2].replace(" ", ""))
                energy_multmatmat.append(valor) 

            if n_linha == 160:
                partes = linha.split("|")
                valor = float(partes[2].replace(" ", ""))
                energy_multmatmat_otimizado.append(valor)

# %% [markdown]
# ### Gráfico

# %%
fig, axs = plt.subplots(1, 2, figsize=(16, 8))

axs[0].plot(x, energy_multmatvet, label='Não otimizado', linestyle='-', marker='o', color='b')
axs[0].plot(x, energy_multmatvet_otimizado, label='Otimizado', linestyle='-', marker='o', color='r')
axs[0].legend()

axs[0].set_xlabel('Tamanho (N)')
axs[0].set_ylabel('Energy (J)')
axs[0].set_title('Matriz x Vetor (multmatvet)', fontsize=16)

axs[1].plot(x, energy_multmatmat, label='Não otimizado', linestyle='-', marker='o', color='b')
axs[1].plot(x, energy_multmatmat_otimizado, label='Otimizado', linestyle='-', marker='o', color='r')
axs[1].legend()

axs[1].set_xlabel('Tamanho (N)')
axs[1].set_ylabel('Energy (J)')
axs[1].set_title('Matriz x Matriz (multmatmat)', fontsize=16)

fig.suptitle('Energy [J]', fontsize=20)

plt.savefig("graficos/energy.png")

plt.show()

# %% [markdown]
# ## FLOPS_DP

# %%
flops_dp_multmatvet = []
flops_dp_multmatvet_otimizado = []
flops_dp_multmatmat = []
flops_dp_multmatmat_otimizado = []

flops_avx_multmatvet = []
flops_avx_multmatvet_otimizado = []
flops_avx_multmatmat = []
flops_avx_multmatmat_otimizado = []

for n in x:
    arquivo = 'FLOPS_DP_' + str(n) + '.txt'
        
    with open("resultados/" + arquivo, 'r') as arquivo:
        linhas = arquivo.readlines()

        for n_linha, linha in enumerate(linhas):
            if n_linha == 40:
                partes = linha.split("|")
                valor = float(partes[2].replace(" ", ""))
                flops_dp_multmatvet.append(valor)
            
            if n_linha == 41:
                partes = linha.split("|")
                valor = float(partes[2].replace(" ", ""))
                flops_avx_multmatvet.append(valor)

            if n_linha == 73:
                partes = linha.split("|")
                valor = float(partes[2].replace(" ", ""))
                flops_dp_multmatvet_otimizado.append(valor) 

            if n_linha == 74:
                partes = linha.split("|")
                valor = float(partes[2].replace(" ", ""))
                flops_avx_multmatvet_otimizado.append(valor)
                
            if n_linha == 106:
                partes = linha.split("|")
                valor = float(partes[2].replace(" ", ""))
                flops_dp_multmatmat.append(valor)
            
            if n_linha == 107:
                partes = linha.split("|")
                valor = float(partes[2].replace(" ", ""))
                flops_avx_multmatmat.append(valor)

            if n_linha == 139:
                partes = linha.split("|")
                valor = float(partes[2].replace(" ", ""))
                flops_dp_multmatmat_otimizado.append(valor) 

            if n_linha == 140:
                partes = linha.split("|")
                valor = float(partes[2].replace(" ", ""))
                flops_avx_multmatmat_otimizado.append(valor)

# %% [markdown]
# ### Gráfico

# %%
fig, axs = plt.subplots(1, 2, figsize=(16, 8))

axs[0].plot(x, flops_dp_multmatvet, label='Não otimizado', linestyle='-', marker='o', color='b')
axs[0].plot(x, flops_dp_multmatvet_otimizado, label='Otimizado', linestyle='-', marker='o', color='r')
axs[0].legend()

axs[0].set_xlabel('Tamanho (N)')
axs[0].set_ylabel('DP [MFLOP/s]')
axs[0].set_title('Matriz x Vetor (multmatvet)', fontsize=16)

axs[1].plot(x, flops_dp_multmatmat, label='Não otimizado', linestyle='-', marker='o', color='b')
axs[1].plot(x, flops_dp_multmatmat_otimizado, label='Otimizado', linestyle='-', marker='o', color='r')
axs[1].legend()

axs[1].set_xlabel('Tamanho (N)')
axs[1].set_ylabel('DP [MFLOP/s]')
axs[1].set_title('Matriz x Matriz (multmatmat)', fontsize=16)

fig.suptitle('FLOPS_DP', fontsize=20)

plt.savefig("graficos/flops_dp.png")

plt.show()

# %%
fig, axs = plt.subplots(1, 2, figsize=(16, 8))

axs[0].plot(x, flops_avx_multmatvet, label='Não otimizado', linestyle='-', marker='o', color='b')
axs[0].plot(x, flops_avx_multmatvet_otimizado, label='Otimizado', linestyle='-', marker='o', color='r')
axs[0].legend()

axs[0].set_xlabel('Tamanho (N)')
axs[0].set_ylabel('AVX DP [MFLOP/s]')
axs[0].set_title('Matriz x Vetor (multmatvet)', fontsize=16)

axs[1].plot(x, flops_avx_multmatmat, label='Não otimizado', linestyle='-', marker='o', color='b')
axs[1].plot(x, flops_avx_multmatmat_otimizado, label='Otimizado', linestyle='-', marker='o', color='r')
axs[1].legend()

axs[1].set_xlabel('Tamanho (N)')
axs[1].set_ylabel('AVX DP [MFLOP/s]')
axs[1].set_title('Matriz x Matriz (multmatmat)', fontsize=16)

fig.suptitle('FLOPS_AVX', fontsize=20)

plt.savefig("graficos/flops_avx.png")

plt.show()

# %% [markdown]
# ## Resumo

# %%
with open('resumo-resultados.txt', 'w') as arquivo:
    arquivo.write("==================================== TEMPO ====================================\n\n")
    arquivo.write("Matriz x Vetor - Não Otimizado\n")
    for n, tempo in zip(x, tempo_multmatvet):
        arquivo.write(str(n))
        arquivo.write(" ")
        arquivo.write(str(tempo))
        arquivo.write("\n")
    arquivo.write("\n")
    
    arquivo.write("Matriz x Vetor - Otimizado\n")
    for n, tempo in zip(x, tempo_multmatvet_otimizado):
        arquivo.write(str(n))
        arquivo.write(" ")
        arquivo.write(str(tempo))
        arquivo.write("\n")
    arquivo.write("\n")

    arquivo.write("Matriz x Matriz - Não Otimizado\n")
    for n, tempo in zip(x, tempo_multmatmat):
        arquivo.write(str(n))
        arquivo.write(" ")
        arquivo.write(str(tempo))
        arquivo.write("\n")
    arquivo.write("\n")

    arquivo.write("Matriz x Matriz - Otimizado\n")
    for n, tempo in zip(x, tempo_multmatmat_otimizado):
        arquivo.write(str(n))
        arquivo.write(" ")
        arquivo.write(str(tempo))
        arquivo.write("\n")
    arquivo.write("==============================================================================================\n\n")

    arquivo.write("==================================== BANDA DE MEMÓRIA (L3) ===================================\n\n")
    arquivo.write("Matriz x Vetor - Não Otimizado\n")
    for n, tempo in zip(x, l3_multmatvet):
        arquivo.write(str(n))
        arquivo.write(" ")
        arquivo.write(str(tempo))
        arquivo.write("\n")
    arquivo.write("\n")
    
    arquivo.write("Matriz x Vetor - Otimizado\n")
    for n, tempo in zip(x, l3_multmatvet_otimizado):
        arquivo.write(str(n))
        arquivo.write(" ")
        arquivo.write(str(tempo))
        arquivo.write("\n")
    arquivo.write("\n")

    arquivo.write("Matriz x Matriz - Não Otimizado\n")
    for n, tempo in zip(x, l3_multmatmat):
        arquivo.write(str(n))
        arquivo.write(" ")
        arquivo.write(str(tempo))
        arquivo.write("\n")
    arquivo.write("\n")

    arquivo.write("Matriz x Matriz - Otimizado\n")
    for n, tempo in zip(x, l3_multmatmat_otimizado):
        arquivo.write(str(n))
        arquivo.write(" ")
        arquivo.write(str(tempo))
        arquivo.write("\n")
    arquivo.write("=====================================================================================\n\n")
    
    arquivo.write("==================================== CACHE MISS L2 ==================================\n\n")
    arquivo.write("Matriz x Vetor - Não Otimizado\n")
    for n, tempo in zip(x, l2_multmatvet):
        arquivo.write(str(n))
        arquivo.write(" ")
        arquivo.write(str(tempo))
        arquivo.write("\n")
    arquivo.write("\n")
    
    arquivo.write("Matriz x Vetor - Otimizado\n")
    for n, tempo in zip(x, l2_multmatvet_otimizado):
        arquivo.write(str(n))
        arquivo.write(" ")
        arquivo.write(str(tempo))
        arquivo.write("\n")
    arquivo.write("\n")

    arquivo.write("Matriz x Matriz - Não Otimizado\n")
    for n, tempo in zip(x, l2_multmatmat):
        arquivo.write(str(n))
        arquivo.write(" ")
        arquivo.write(str(tempo))
        arquivo.write("\n")
    arquivo.write("\n")

    arquivo.write("Matriz x Matriz - Otimizado\n")
    for n, tempo in zip(x, l2_multmatmat_otimizado):
        arquivo.write(str(n))
        arquivo.write(" ")
        arquivo.write(str(tempo))
        arquivo.write("\n")
    arquivo.write("====================================================================================\n\n")
    
    arquivo.write("==================================== ENERGY [J] ====================================\n\n")
    arquivo.write("Matriz x Vetor - Não Otimizado\n")
    for n, tempo in zip(x, energy_multmatvet):
        arquivo.write(str(n))
        arquivo.write(" ")
        arquivo.write(str(tempo))
        arquivo.write("\n")
    arquivo.write("\n")
    
    arquivo.write("Matriz x Vetor - Otimizado\n")
    for n, tempo in zip(x, energy_multmatvet_otimizado):
        arquivo.write(str(n))
        arquivo.write(" ")
        arquivo.write(str(tempo))
        arquivo.write("\n")
    arquivo.write("\n")

    arquivo.write("Matriz x Matriz - Não Otimizado\n")
    for n, tempo in zip(x, energy_multmatmat):
        arquivo.write(str(n))
        arquivo.write(" ")
        arquivo.write(str(tempo))
        arquivo.write("\n")
    arquivo.write("\n")

    arquivo.write("Matriz x Matriz - Otimizado\n")
    for n, tempo in zip(x, energy_multmatmat_otimizado):
        arquivo.write(str(n))
        arquivo.write(" ")
        arquivo.write(str(tempo))
        arquivo.write("\n")
    arquivo.write("=====================================================================================\n\n")

    arquivo.write("==================================== FLOPS_DP =======================================\n\n")
    arquivo.write("Matriz x Vetor - Não Otimizado\n")
    for n, tempo in zip(x, flops_dp_multmatvet):
        arquivo.write(str(n))
        arquivo.write(" ")
        arquivo.write(str(tempo))
        arquivo.write("\n")
    arquivo.write("\n")
    
    arquivo.write("Matriz x Vetor - Otimizado\n")
    for n, tempo in zip(x, flops_dp_multmatvet_otimizado):
        arquivo.write(str(n))
        arquivo.write(" ")
        arquivo.write(str(tempo))
        arquivo.write("\n")
    arquivo.write("\n")

    arquivo.write("Matriz x Matriz - Não Otimizado\n")
    for n, tempo in zip(x, flops_dp_multmatmat):
        arquivo.write(str(n))
        arquivo.write(" ")
        arquivo.write(str(tempo))
        arquivo.write("\n")
    arquivo.write("\n")

    arquivo.write("Matriz x Matriz - Otimizado\n")
    for n, tempo in zip(x, flops_dp_multmatmat_otimizado):
        arquivo.write(str(n))
        arquivo.write(" ")
        arquivo.write(str(tempo))
        arquivo.write("\n")
    arquivo.write("=====================================================================================\n\n")

    arquivo.write("==================================== FLOPS_AVX ======================================\n\n")
    arquivo.write("Matriz x Vetor - Não Otimizado\n")
    for n, tempo in zip(x, flops_avx_multmatvet):
        arquivo.write(str(n))
        arquivo.write(" ")
        arquivo.write(str(tempo))
        arquivo.write("\n")
    arquivo.write("\n")
    
    arquivo.write("Matriz x Vetor - Otimizado\n")
    for n, tempo in zip(x, flops_avx_multmatvet_otimizado):
        arquivo.write(str(n))
        arquivo.write(" ")
        arquivo.write(str(tempo))
        arquivo.write("\n")
    arquivo.write("\n")

    arquivo.write("Matriz x Matriz - Não Otimizado\n")
    for n, tempo in zip(x, flops_avx_multmatmat):
        arquivo.write(str(n))
        arquivo.write(" ")
        arquivo.write(str(tempo))
        arquivo.write("\n")
    arquivo.write("\n")

    arquivo.write("Matriz x Matriz - Otimizado\n")
    for n, tempo in zip(x, flops_avx_multmatmat_otimizado):
        arquivo.write(str(n))
        arquivo.write(" ")
        arquivo.write(str(tempo))
        arquivo.write("\n")
    arquivo.write("=====================================================================================\n\n")
